# %%
import torch

# Tensor Math & Comparison Operations

x = torch.tensor([1, 2, 3])
y = torch.tensor([9, 8, 7])

# Addition
z1 = torch.empty(3)
torch.add(x, y, out=z1)

z2 = torch.add(x, y)
z = x + y
print(z)

# Subtraction
z = x - y
print(z)

# Division
z = torch.true_divide(x, y)
print(z)

# inplace operations
t = torch.zeros(3)
t.add_(x)
print(x)
t += x # t = t + x

# Exponentiation
z = x.pow(2)
print(z)

# Simple comparison
z = x > 0
z = x < 0
print(z)

# Matrix Multiplication
x1 = torch.rand((2, 5))
x2 = torch.rand((5, 3))
x3 = torch.mm(x1, x2)
x3 = x1.mm(x2)

# matrix exponentiation
matrix_exp = torch.rand(5, 5)
print(matrix_exp.matrix_power(3))

# element wise mult
z = x * y
print(z)

# dot product
z = torch.dot(x, y)
print(z)

# Batch Matrix Multiplication
batch = 32
n = 10
m = 20
p = 30

tensor1 = torch.rand((batch, n, m))
tensor2 = torch.rand(batch, m ,p)
out_bmm = torch.bmm(tensor1, tensor2)
print(tensor1, tensor2, out_bmm)

# Example of Broadcasting
x1 = torch.rand((5, 5))
x2 = torch.rand((1, 5))

z = x1 - x2
print(z)

# Other useful tensor operations
print(x)
sum_x = torch.sum(x, dim=0)
print(sum_x)
values, indices = torch.max(x, dim=0)
print(values, indices)
abs_x = torch.abs(x)
z = torch.argmax(x, dim=0)
print(z)
mean_x = torch.mean(x.float(), dim=0)
print(mean_x)
z = torch.eq(x, y)
torch.sort(y, dim=0, descending=False)
# Out:
# tensor([10, 10, 10])
# tensor([-8, -6, -4])
# tensor([0.1111, 0.2500, 0.4286])
# tensor([1, 2, 3])
# tensor([1, 4, 9])
# tensor([False, False, False])
# tensor([[2.9111, 3.4871, 3.8643, 4.3177, 2.3594],
#         [2.8875, 3.4219, 3.9869, 4.2479, 2.4524],
#         [3.9384, 4.2494, 4.7508, 5.4910, 2.8002],
#         [2.1927, 2.4632, 2.8732, 3.1301, 1.7401],
#         [2.2959, 2.5469, 3.0051, 3.1659, 1.6725]])
# tensor([ 9, 16, 21])
# tensor(46)
# tensor([[[9.3631e-03, 7.8828e-01, 3.7822e-01,  ..., 7.3606e-01,
#           3.2938e-01, 9.2400e-01],
#          [4.5570e-01, 5.2127e-01, 5.0953e-01,  ..., 2.2695e-02,
#           1.0865e-01, 4.3104e-01],
#          [4.2337e-01, 3.4099e-01, 8.3240e-02,  ..., 5.8638e-01,
#           4.3955e-01, 3.8536e-01],
#          ...,
#          [4.1015e-01, 1.9810e-01, 4.0496e-01,  ..., 1.8200e-01,
#           4.7709e-01, 4.2732e-01],
#          [9.5886e-01, 9.7663e-02, 3.8787e-01,  ..., 5.1353e-01,
#           8.9851e-01, 7.5664e-01],
#          [8.1078e-01, 2.0420e-01, 8.6078e-01,  ..., 6.3658e-02,
#           7.7317e-01, 7.9682e-01]],
#
#         [[3.0182e-01, 1.4374e-01, 4.4446e-01,  ..., 6.7996e-01,
#           9.2839e-01, 4.6144e-01],
#          [6.5254e-01, 7.1206e-01, 6.4919e-01,  ..., 7.7589e-01,
#           7.3454e-01, 4.9637e-01],
#          [6.6147e-01, 1.7244e-02, 9.2292e-03,  ..., 9.5766e-02,
#           2.1622e-01, 2.5981e-01],
#          ...,
#          [6.9297e-01, 6.2089e-01, 4.2780e-01,  ..., 6.6230e-01,
#           9.8397e-01, 7.9920e-01],
#          [8.1232e-01, 8.6311e-01, 8.5644e-02,  ..., 7.1316e-01,
#           4.1835e-01, 4.9064e-01],
#          [3.7150e-01, 1.2716e-01, 6.4143e-01,  ..., 3.5150e-01,
#           5.3212e-01, 8.1583e-01]],
#
#         [[5.0951e-01, 9.0874e-01, 6.2550e-01,  ..., 2.9111e-01,
#           3.0234e-02, 5.2961e-01],
#          [7.2476e-01, 4.6311e-01, 8.7900e-01,  ..., 8.0769e-01,
#           5.6975e-01, 4.8831e-01],
#          [1.2049e-01, 1.8148e-01, 4.4841e-01,  ..., 6.7889e-01,
#           8.5725e-01, 8.3356e-01],
#          ...,
#          [8.9258e-01, 4.3095e-01, 8.2579e-01,  ..., 3.6841e-01,
#           1.5180e-01, 9.6854e-01],
#          [5.7171e-01, 7.7716e-01, 5.2003e-01,  ..., 9.0173e-01,
#           6.3706e-01, 2.9393e-02],
#          [1.1326e-01, 3.1401e-01, 4.5524e-01,  ..., 2.7365e-01,
#           3.6991e-01, 6.8956e-01]],
#
#         ...,
#
#         [[6.7544e-01, 7.6270e-01, 1.2003e-01,  ..., 3.2553e-01,
#           6.3405e-01, 5.1842e-02],
#          [2.2884e-01, 8.4786e-01, 5.2044e-01,  ..., 2.5644e-01,
#           5.0562e-01, 3.5210e-01],
#          [7.4409e-01, 2.3386e-01, 8.2111e-01,  ..., 6.0197e-01,
#           7.8328e-01, 4.4494e-01],
#          ...,
#          [8.0841e-01, 7.5850e-01, 5.5309e-01,  ..., 5.3946e-01,
#           3.3949e-01, 1.1385e-01],
#          [2.8269e-01, 1.8074e-02, 4.4580e-01,  ..., 2.6442e-01,
#           3.5174e-02, 6.1615e-01],
#          [5.8045e-02, 9.2544e-01, 9.8889e-01,  ..., 1.7991e-01,
#           4.4450e-01, 8.6619e-01]],
#
#         [[1.4052e-01, 6.6925e-01, 9.7452e-01,  ..., 4.5993e-01,
#           1.3185e-03, 9.6186e-02],
#          [9.7219e-01, 2.4363e-01, 2.3790e-01,  ..., 5.9065e-01,
#           6.0240e-01, 5.2112e-01],
#          [4.0933e-01, 1.5023e-01, 3.8855e-01,  ..., 3.5193e-01,
#           9.5462e-01, 1.3072e-02],
#          ...,
#          [2.2050e-01, 9.8603e-01, 4.6095e-01,  ..., 7.8286e-02,
#           5.4496e-02, 6.2718e-01],
#          [1.9339e-01, 6.0767e-01, 3.1620e-01,  ..., 7.7561e-01,
#           3.3669e-01, 9.8351e-01],
#          [9.7792e-01, 5.7102e-01, 8.5428e-01,  ..., 3.9481e-01,
#           9.7234e-01, 4.2220e-01]],
#
#         [[8.6025e-01, 1.9598e-01, 8.8494e-01,  ..., 5.6940e-01,
#           5.0112e-01, 9.5122e-01],
#          [4.8802e-01, 7.2850e-01, 1.6204e-01,  ..., 5.7443e-01,
#           2.1345e-01, 5.3603e-01],
#          [1.4774e-01, 8.0792e-01, 4.6139e-01,  ..., 7.0256e-02,
#           9.7012e-01, 3.4143e-01],
#          ...,
#          [5.9344e-01, 1.1298e-01, 5.5584e-01,  ..., 2.7603e-01,
#           9.5342e-01, 4.4286e-05],
#          [8.5883e-01, 2.1775e-01, 2.2037e-01,  ..., 3.1441e-01,
#           8.3758e-01, 6.3224e-01],
#          [2.4311e-01, 6.8228e-01, 1.9026e-01,  ..., 3.5146e-01,
#           2.3692e-01, 8.7078e-01]]]) tensor([[[0.4601, 0.9160, 0.6844,  ..., 0.2377, 0.1379, 0.8700],
#          [0.2981, 0.9232, 0.1262,  ..., 0.6621, 0.9061, 0.3862],
#          [0.0443, 0.5072, 0.9441,  ..., 0.4504, 0.0752, 0.9363],
#          ...,
#          [0.3957, 0.0204, 0.5348,  ..., 0.4484, 0.0580, 0.4400],
#          [0.7604, 0.2380, 0.3773,  ..., 0.3625, 0.4882, 0.6159],
#          [0.7235, 0.6284, 0.3622,  ..., 0.4321, 0.0779, 0.4040]],
#
#         [[0.3918, 0.6894, 0.3219,  ..., 0.5399, 0.5717, 0.9068],
#          [0.3936, 0.7700, 0.4306,  ..., 0.9930, 0.5551, 0.5743],
#          [0.0134, 0.7512, 0.2504,  ..., 0.9698, 0.5881, 0.7852],
#          ...,
#          [0.9774, 0.2195, 0.7281,  ..., 0.6398, 0.5674, 0.6348],
#          [0.6696, 0.7258, 0.1028,  ..., 0.2507, 0.0158, 0.7900],
#          [0.8062, 0.5762, 0.7506,  ..., 0.7642, 0.4091, 0.0160]],
#
#         [[0.5546, 0.9314, 0.7433,  ..., 0.7814, 0.6012, 0.3692],
#          [0.8243, 0.8934, 0.7607,  ..., 0.8757, 0.6322, 0.6142],
#          [0.8714, 0.5315, 0.5388,  ..., 0.3388, 0.2239, 0.6978],
#          ...,
#          [0.5040, 0.4887, 0.2945,  ..., 0.4431, 0.3903, 0.2217],
#          [0.4691, 0.1482, 0.1264,  ..., 0.4823, 0.9779, 0.2491],
#          [0.5525, 0.8042, 0.2126,  ..., 0.5388, 0.1059, 0.1966]],
#
#         ...,
#
#         [[0.9971, 0.7784, 0.6767,  ..., 0.6929, 0.5201, 0.8013],
#          [0.5576, 0.3316, 0.7738,  ..., 0.3555, 0.6312, 0.1604],
#          [0.9787, 0.1481, 0.0732,  ..., 0.8867, 0.9366, 0.8589],
#          ...,
#          [0.4801, 0.8014, 0.3386,  ..., 0.3260, 0.2831, 0.5317],
#          [0.3903, 0.6656, 0.4714,  ..., 0.5587, 0.0191, 0.0351],
#          [0.6365, 0.5826, 0.8659,  ..., 0.2660, 0.3863, 0.2290]],
#
#         [[0.0070, 0.1994, 0.7877,  ..., 0.6310, 0.5383, 0.4143],
#          [0.7168, 0.8966, 0.5613,  ..., 0.4643, 0.4265, 0.9407],
#          [0.1314, 0.3329, 0.8610,  ..., 0.6404, 0.9426, 0.0510],
#          ...,
#          [0.3103, 0.3466, 0.6382,  ..., 0.9007, 0.1519, 0.7545],
#          [0.7022, 0.8143, 0.4965,  ..., 0.0692, 0.0178, 0.0237],
#          [0.5295, 0.9267, 0.5721,  ..., 0.4245, 0.5684, 0.2858]],
#
#         [[0.1494, 0.7667, 0.1310,  ..., 0.8809, 0.4437, 0.2532],
#          [0.6075, 0.0074, 0.1242,  ..., 0.4043, 0.2805, 0.2953],
#          [0.0460, 0.9569, 0.5451,  ..., 0.0913, 0.2432, 0.1915],
#          ...,
#          [0.5036, 0.8361, 0.8314,  ..., 0.2104, 0.2083, 0.1418],
#          [0.9734, 0.3348, 0.9820,  ..., 0.6849, 0.2516, 0.4717],
#          [0.2326, 0.6305, 0.2867,  ..., 0.5298, 0.5107, 0.0243]]]) tensor([[[3.8677, 4.8850, 3.9262,  ..., 3.4621, 2.6875, 4.3929],
#          [3.5806, 5.1452, 3.6941,  ..., 2.5527, 2.3891, 4.1674],
#          [4.0445, 4.9545, 3.7313,  ..., 3.1967, 2.6038, 4.2429],
#          ...,
#          [4.6802, 6.6461, 5.0314,  ..., 3.7576, 3.7337, 5.5206],
#          [5.2668, 7.5694, 6.0472,  ..., 3.9335, 4.1190, 7.0254],
#          [4.6949, 6.8082, 4.9577,  ..., 3.7162, 3.7961, 5.4250]],
#
#         [[5.0450, 4.6329, 3.8078,  ..., 4.9908, 4.4386, 4.3769],
#          [5.9586, 6.2538, 5.0630,  ..., 6.1609, 5.7115, 6.6826],
#          [3.2294, 3.4985, 3.1330,  ..., 3.1407, 2.8083, 3.8897],
#          ...,
#          [6.3968, 6.1555, 5.4154,  ..., 6.4675, 5.7845, 6.7989],
#          [5.6012, 5.4633, 4.6547,  ..., 5.6884, 5.2611, 5.4692],
#          [5.9360, 5.6662, 4.8386,  ..., 6.1389, 5.4283, 4.9007]],
#
#         [[5.1975, 4.6944, 4.9836,  ..., 4.6289, 5.1013, 4.8315],
#          [5.8453, 6.3560, 6.2845,  ..., 5.6045, 7.4517, 6.4669],
#          [4.8049, 4.7255, 4.6316,  ..., 4.8492, 5.3271, 5.0568],
#          ...,
#          [3.8994, 5.3364, 4.6948,  ..., 4.5692, 3.9193, 4.4784],
#          [5.3499, 5.4429, 6.0054,  ..., 4.9291, 6.7051, 5.2587],
#          [3.4864, 4.7496, 3.9871,  ..., 4.1194, 4.5820, 4.0829]],
#
#         ...,
#
#         [[6.4887, 6.4550, 6.7874,  ..., 5.3776, 5.2497, 5.4401],
#          [5.9967, 5.3665, 5.9160,  ..., 4.8073, 4.7368, 4.7888],
#          [6.3414, 5.7064, 5.7445,  ..., 4.6222, 4.6837, 4.7718],
#          ...,
#          [6.2141, 4.5742, 5.6739,  ..., 4.4372, 4.4777, 4.0183],
#          [4.0659, 3.8285, 3.5672,  ..., 2.8244, 3.1843, 3.5743],
#          [6.1164, 4.8041, 5.3499,  ..., 4.5974, 4.4457, 5.2397]],
#
#         [[4.0517, 4.4399, 5.2231,  ..., 4.5885, 4.4854, 5.1362],
#          [5.0616, 5.3037, 5.6247,  ..., 4.8745, 4.8681, 4.8185],
#          [4.7960, 3.6808, 5.2341,  ..., 4.1902, 4.6633, 4.6610],
#          ...,
#          [3.9800, 4.6059, 5.0000,  ..., 3.4898, 4.0703, 5.0111],
#          [5.3519, 5.9146, 5.9004,  ..., 5.4589, 4.7258, 5.9498],
#          [4.8767, 5.5440, 6.0794,  ..., 4.9628, 5.1018, 5.8158]],
#
#         [[3.9816, 6.1341, 5.3654,  ..., 5.1214, 5.1535, 3.9155],
#          [3.7146, 4.7353, 3.8931,  ..., 3.9943, 3.6170, 2.9702],
#          [5.3696, 5.2474, 4.4688,  ..., 4.4579, 4.9567, 3.7483],
#          ...,
#          [4.6564, 6.0801, 4.6270,  ..., 5.3002, 5.4473, 5.1302],
#          [4.7680, 6.4029, 4.9780,  ..., 5.4844, 5.7230, 4.0444],
#          [4.5331, 5.2501, 3.4478,  ..., 4.7730, 5.1421, 4.2968]]])
# tensor([[ 0.2410,  0.5608,  0.1094, -0.6239, -0.2731],
#         [-0.5127, -0.1549,  0.0602,  0.3018,  0.1135],
#         [-0.4653,  0.4914,  0.0030, -0.4682, -0.5630],
#         [ 0.1459, -0.0767,  0.4035, -0.6431, -0.7196],
#         [-0.4149, -0.0172, -0.1643, -0.0124, -0.2469]])
# tensor([1, 2, 3])
# tensor(6)
# tensor(3) tensor(2)
# tensor(2)
# tensor(2.)
# torch.return_types.sort(
# values=tensor([7, 8, 9]),
# indices=tensor([2, 1, 0]))
